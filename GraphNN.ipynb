441201687152, null, 0.5866731512397676, 0.6143153829596603, null, 0.5866731512397676, 0.6942730119224528, null, 0.5866731512397676, 0.5922053290665381, null, 0.5866731512397676, 0.6707616147949481, null, 0.6942730119224528, 0.6143153829596603, null, 0.6942730119224528, 0.6707616147949481, null, 0.6942730119224528, 0.7120866313624231, null, 0.6942730119224528, 0.5922053290665381, null, 0.7284894107202086, 0.6782336496290771, null, 0.7284894107202086, 0.7120866313624231, null, 0.3600868982104617, 0.2807983049307169, null, 0.3600868982104617, 0.44482706002840355, null, 0.6143153829596603, 0.5922053290665381, null, 0.6143153829596603, 0.6707616147949481, null, 0.028898963557938195, 0.02919823396844734, null, 0.028898963557938195, 0.0880041836397234, null, 0.011953592124292478, 0.013393424285558564, null, 0.011953592124292478, 0.04534582631405548, null, 0.7704817186815088, 0.7522207177394132, null, 0.7704817186815088, 0.766526735108974, null, 0.7704817186815088, 0.7467071448954838, null, 0.34169194476633136, 0.328922180284108, null, 0.34169194476633136, 0.4422448781240408, null, 0.34169194476633136, 0.27470548149498863, null, 0.0880041836397234, 0.02919823396844734, null, 0.5922053290665381, 0.6707616147949481, null, 0.6707616147949481, 0.7120866313624231, null, 0.7467071448954838, 0.766526735108974, null, 0.7467071448954838, 0.7522207177394132, null, 0.17496147207687485,  ...

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("book.csv")
# pick only important weights (hard threshold)
df = df.loc[df['weight']>10, :]
df
# Out:
#                               Source              Target  ... weight  book
# 8    Aemon-Targaryen-(Maester-Aemon)        Jeor-Mormont  ...     13     1
# 9    Aemon-Targaryen-(Maester-Aemon)            Jon-Snow  ...     34     1
# 16                Aerys-II-Targaryen    Robert-Baratheon  ...     12     1
# 17                              Aggo  Daenerys-Targaryen  ...     11     1
# 30                    Alliser-Thorne            Jon-Snow  ...     32     1
# ..                               ...                 ...  ...    ...   ...
# 658                   Sandor-Clegane         Sansa-Stark  ...     23     1
# 664                             Shae    Tyrion-Lannister  ...     12     1
# 666                           Shagga    Tyrion-Lannister  ...     17     1
# 676                 Tyrion-Lannister     Tywin-Lannister  ...     40     1
# 683                     Waymar-Royce     Will-(prologue)  ...     18     1
#
# [175 rows x 5 columns]

# %%
import networkx as nx
G = nx.from_pandas_edgelist(df, 
                            source='Source', 
                            target='Target', 
                            edge_attr='weight')
print("No of unique characters:", len(G.nodes))
print("No of connections:", len(G.edges))
# Out:
# No of unique characters: 80
# No of connections: 175

# %%
graphs_viz_options = [nx.draw, nx.draw_networkx, nx.draw_circular, nx.draw_kamada_kawai, nx.draw_random, nx.draw_shell, nx.draw_spring]

selected_graph_option = 0

plt.figure(figsize=(20,15), dpi=200) 
graphs_viz_options[selected_graph_option](G)
